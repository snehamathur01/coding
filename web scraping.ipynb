# %% [markdown]
# <a href="https://colab.research.google.com/github/snehamathur01/coding/blob/master/web%20scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install bs4

# %%
from bs4 import BeautifulSoup
import requests
url='https://en.wikipedia.org/wiki/Alien_(film)'
#sedding request to url and reading the response
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Alien (film) - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Alien_(film)","wgTitle":"Alien (film)","wgCurRevisionId":903249362,"wgRevisionId":903249362,"wgArticleId":23487440,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","Articles with short description","Use mdy dates from October 2013","Good articles","Commons category link is on Wikidata","Wikipedia articles with BIBSYS identifiers","Wikipedia articles with BNE identifiers","Wikipedia articles with BNF identifiers","Wikipedia articles with GND identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with SUDO
# ...

# %%
#parsing library -html.parser and lxml
soup=BeautifulSoup(response.text,"lxml")

# %%
for Alink in soup.find_all('a'):
  #print (Alink)
  print(Alink.get('href'))
# Out:
# None
# /wiki/Wikipedia:Good_articles
# #mw-head
# #p-search
# /wiki/Aliens_(film)
# /wiki/File:Alien_movie_poster.jpg
# /wiki/Ridley_Scott
# /wiki/Gordon_Carroll
# /wiki/David_Giler
# /wiki/Walter_Hill
# /wiki/Dan_O%27Bannon
# /wiki/Ronald_Shusett
# /wiki/Tom_Skerritt
# /wiki/Sigourney_Weaver
# /wiki/Veronica_Cartwright
# /wiki/Harry_Dean_Stanton
# /wiki/John_Hurt
# /wiki/Ian_Holm
# /wiki/Yaphet_Kotto
# /wiki/Jerry_Goldsmith
# /wiki/Derek_Vanlint
# /wiki/Terry_Rawlings
# /wiki/20th_Century_Fox
# /wiki/Brandywine_Productions
# #cite_note-mfb-review-2
# #cite_note-afi-3
# #cite_note-limitedrelease-4
# #cite_note-5
# #cite_note-mfb-review-2
# #cite_note-afi-3
# #cite_note-numbers-6
# #cite_note-box_office_mojo-7
# #cite_note-8
# #cite_note-numbers-6
# #cite_note-box_office_mojo-7
# /wiki/Science_fiction_film
# /wiki/Horror_film
# /wiki/Ridley_Scott
# /wiki/Dan_O%27Bannon
# /wiki/Ronald_Shusett
# /wiki/Alien_(creature_in_Alien_franchise)
# /wiki/Tom_Skerritt
# /wiki/Sigourney_Weaver
# ...

# %%
for ptag in soup.find_all('p'):
   # print(ptag)
    for  btag in ptag.find_all('b'):
       print(btag.text)
# Out:
# Alien
# Notes
# Bibliography
# Further reading

# %%
import pandas as pd
list=[1,2,3,4]
list1=[3,4,5,5]
df=pd.DataFrame([list,list1],columns=['age','value','name','marks'])
df
# Out:
#    age  value  name  marks
# 0    1      2     3      4
# 1    3      4     5      5

# %%
l1=['sneha',20,90,1700]
l2=['neha',18,79,1200]
l3=['eha',21,78,4555]
df=pd.DataFrame([l1,l2,l3],columns=['name','age','marks','rolln'])
df
# Out:
#     name  age  marks  rolln
# 0  sneha   20     90   1700
# 1   neha   18     79   1200
# 2    eha   21     78   4555
